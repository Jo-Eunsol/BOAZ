# %% [markdown]
# # 1번째 방법 -  Beautiful Soup을 이용한 웹크롤링
#
# Beautiful Soup 공식 홈페이지 : https://www.crummy.com/software/BeautifulSoup/bs4/doc

# %% [markdown]
# ## 크롤링하기 위한 준비

# %%
import numpy as np # pandas 라이브러리 의존성 때문에
import pandas as pd # 가져온 데이터를 가공하기 위해
from tqdm import tqdm_notebook # 진행률을 표시하기 위해
from bs4 import BeautifulSoup
from urllib.request import urlopen

# %% [markdown]
# ## Example 1 - 네이버 환율 정보 가져오기

# %%
# url을 통해서 요청하는 부분
url_base = 'https://finance.naver.com/marketindex/exchangeList.nhn'

# 요청해서 가져온 내용을 page 객체에 담음
page = urlopen(url_base)

# page를 html.parser형태로 parsing
# soup 객체에 html을 전부 긁어옴
soup = BeautifulSoup(page,'html.parser')

# %%
# soup를 한번 확인해보자
# 크롬에서 개발자도구를 통해서 보던 내용과 동일하다
print(soup)
# Out:
# <html lang="ko">
# <head>
# <title>네이버 금융</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="text/javascript" http-equiv="Content-Script-Type"/>
# <meta content="text/css" http-equiv="Content-Style-Type"/>
# <link href="/css/finance.css?20190306113304" rel="stylesheet" type="text/css"/>
# <script language="javascript">document.domain="naver.com";</script>
# <script src="/js/info/jindo.min.ns.1.5.3.euckr.js" type="text/javascript"></script>
# <script src="/js/lcslog.js?20190306113304" type="text/javascript"></script>
# </head>
# <body>
# <div class="tbl_area">
# <table border="1" class="tbl_exchange" summary="환전 고시 환율 리스트">
# <caption>환전 고시 환율</caption>
# <colgroup>
# <col width="162"/>
# <col width="92"/>
# <col width="92"/>
# <col width="92"/>
# <col width="93"/>
# <col width="92"/>
# <col width="90"/>
# </colgroup>
# <thead>
# <tr>
# <th class="th_ex1" rowspan="2">
# <a href="#" onclick="javascript:changeOrder('exchange'); return false;"><span>통화명</span></a></th>
# <th class="th_ex2" rowspan="2"><span>매매기준율</span></th>
# <th class="th_ex3" colspan="2"><span>현찰</span></th>
# <th class="th_ex4" colspan="2"><span>송금</span></th>
# <th class="th_ex6" rowspan="2"><span>미화환산율</span></th>
# </tr>
# <tr>
# <th class="th_ex7"><span>사실 때 </span></th>
# <th class="th_ex8"><span>파실 때 </span></th>
# <th class="th_ex9"><span>보내실 때 </span></th>
# <th class="th_ex10"><span>받으실 때</span></th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_USDKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_USDKRW', '1', event);" target="_parent">
#
#
#
#
# 					미국 USD
#
# 				</a></td>
# <td class="sale">1,134.50</td>
# <td>1,154.35</td>
# <td>1,114.65</td>
# <td>1,145.60</td>
# <td>1,123.40</td>
# <td>1.000</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_EURKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_EURKRW', '2', event);" target="_parent">
#
#
#
#
# 					유럽연합 EUR
#
# 				</a></td>
# <td class="sale">1,275.52</td>
# <td>1,300.90</td>
# <td>1,250.14</td>
# <td>1,288.27</td>
# <td>1,262.77</td>
# <td>1.124</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_JPYKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_JPYKRW', '3', event);" target="_parent">
#
# 					일본 JPY (100엔)
#
#
#
#
# 				</a></td>
# <td class="sale">1,019.73</td>
# <td>1,037.57</td>
# <td>1,001.89</td>
# <td>1,029.72</td>
# <td>1,009.74</td>
# <td>0.899</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_CNYKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_CNYKRW', '4', event);" target="_parent">
#
#
#
#
# 					중국 CNY
#
# 				</a></td>
# <td class="sale">168.53</td>
# <td>176.95</td>
# <td>160.11</td>
# <td>170.21</td>
# <td>166.85</td>
# <td>0.149</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_HKDKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_HKDKRW', '5', event);" target="_parent">
#
#
#
#
# 					홍콩 HKD
#
# 				</a></td>
# <td class="sale">144.53</td>
# <td>147.37</td>
# <td>141.69</td>
# <td>145.97</td>
# <td>143.09</td>
# <td>0.127</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_TWDKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_TWDKRW', '6', event);" target="_parent">
#
#
#
#
# 					대만 TWD
#
# 				</a></td>
# <td class="sale">36.70</td>
# <td>41.50</td>
# <td>34.14</td>
# <td>0.00</td>
# <td>0.00</td>
# <td>0.032</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_GBPKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_GBPKRW', '7', event);" target="_parent">
#
#
#
#
# 					영국 GBP
#
# 				</a></td>
# <td class="sale">1,473.66</td>
# <td>1,502.69</td>
# <td>1,444.63</td>
# <td>1,488.39</td>
# <td>1,458.93</td>
# <td>1.299</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_OMRKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_OMRKRW', '8', event);" target="_parent">
#
#
#
#
# 					오만 OMR
#
# 				</a></td>
# <td class="sale">2,946.60</td>
# <td>3,208.84</td>
# <td>2,769.81</td>
# <td>0.00</td>
# <td>0.00</td>
# <td>2.597</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_CADKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_CADKRW', '9', event);" target="_parent">
#
#
#
#
# 					캐나다 CAD
#
# 				</a></td>
# <td class="sale">845.44</td>
# <td>862.09</td>
# <td>828.79</td>
# <td>853.89</td>
# <td>836.99</td>
# <td>0.745</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_CHFKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_CHFKRW', '10', event);" target="_parent">
#
#
#
#
# 					스위스 CHF
#
# 				</a></td>
# <td class="sale">1,124.32</td>
# <td>1,146.46</td>
# <td>1,102.18</td>
# <td>1,135.56</td>
# <td>1,113.08</td>
# <td>0.991</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_SEKKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_SEKKRW', '11', event);" target="_parent">
#
#
#
#
# 					스웨덴 SEK
#
# 				</a></td>
# <td class="sale">120.55</td>
# <td>123.50</td>
# <td>117.60</td>
# <td>121.75</td>
# <td>119.35</td>
# <td>0.106</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_AUDKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_AUDKRW', '12', event);" target="_parent">
#
#
#
#
# 					호주 AUD
#
# 				</a></td>
# <td class="sale">799.14</td>
# <td>814.88</td>
# <td>783.40</td>
# <td>807.13</td>
# <td>791.15</td>
# <td>0.704</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_NZDKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_NZDKRW', '13', event);" target="_parent">
#
#
#
#
# 					뉴질랜드 NZD
#
# 				</a></td>
# <td class="sale">772.25</td>
# <td>787.46</td>
# <td>757.04</td>
# <td>779.97</td>
# <td>764.53</td>
# <td>0.681</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_CZKKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_CZKKRW', '14', event);" target="_parent">
#
#
#
#
# 					체코 CZK
#
# 				</a></td>
# <td class="sale">49.71</td>
# <td>53.93</td>
# <td>45.24</td>
# <td>50.25</td>
# <td>49.17</td>
# <td>0.044</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_CLPKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_CLPKRW', '15', event);" target="_parent">
#
#
#
#
# 					칠레 CLP
#
# 				</a></td>
# <td class="sale">1.69</td>
# <td>1.82</td>
# <td>1.56</td>
# <td>0.00</td>
# <td>0.00</td>
# <td>0.002</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_TRYKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_TRYKRW', '16', event);" target="_parent">
#
#
#
#
# 					터키 TRY
#
# 				</a></td>
# <td class="sale">208.66</td>
# <td>240.16</td>
# <td>188.22</td>
# <td>210.95</td>
# <td>206.37</td>
# <td>0.184</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_MNTKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_MNTKRW', '17', event);" target="_parent">
#
#
#
#
# 					몽골 MNT
#
# 				</a></td>
# <td class="sale">0.43</td>
# <td>0.00</td>
# <td>0.00</td>
# <td>0.00</td>
# <td>0.00</td>
# <td>0.000</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_ILSKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_ILSKRW', '18', event);" target="_parent">
#
#
#
#
# 					이스라엘 ILS
#
# 				</a></td>
# <td class="sale">313.48</td>
# <td>344.82</td>
# <td>288.41</td>
# <td>0.00</td>
# <td>0.00</td>
# <td>0.276</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_DKKKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_DKKKRW', '19', event);" target="_parent">
#
#
#
#
# 					덴마크 DKK
#
# 				</a></td>
# <td class="sale">170.97</td>
# <td>175.15</td>
# <td>166.79</td>
# <td>172.67</td>
# <td>169.27</td>
# <td>0.151</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_NOKKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_NOKKRW', '20', event);" target="_parent">
#
#
#
#
# 					노르웨이 NOK
#
# 				</a></td>
# <td class="sale">130.60</td>
# <td>133.79</td>
# <td>127.41</td>
# <td>131.90</td>
# <td>129.30</td>
# <td>0.115</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_SARKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_SARKRW', '21', event);" target="_parent">
#
#
#
#
# 					사우디아라비아 SAR
#
# 				</a></td>
# <td class="sale">302.51</td>
# <td>321.56</td>
# <td>281.64</td>
# <td>305.53</td>
# <td>299.49</td>
# <td>0.267</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_KWDKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_KWDKRW', '22', event);" target="_parent">
#
#
#
#
# 					쿠웨이트 KWD
#
# 				</a></td>
# <td class="sale">3,731.17</td>
# <td>3,973.69</td>
# <td>3,432.68</td>
# <td>3,768.48</td>
# <td>3,693.86</td>
# <td>3.289</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_BHDKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_BHDKRW', '23', event);" target="_parent">
#
#
#
#
# 					바레인 BHD
#
# 				</a></td>
# <td class="sale">3,009.20</td>
# <td>3,201.78</td>
# <td>2,768.47</td>
# <td>3,039.29</td>
# <td>2,979.11</td>
# <td>2.652</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_AEDKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_AEDKRW', '24', event);" target="_parent">
#
#
#
#
# 					아랍에미리트 AED
#
# 				</a></td>
# <td class="sale">308.86</td>
# <td>325.84</td>
# <td>287.55</td>
# <td>311.94</td>
# <td>305.78</td>
# <td>0.272</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_JODKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_JODKRW', '25', event);" target="_parent">
#
#
#
#
# 					요르단 JOD
#
# 				</a></td>
# <td class="sale">1,602.29</td>
# <td>1,744.89</td>
# <td>1,474.11</td>
# <td>0.00</td>
# <td>0.00</td>
# <td>1.412</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_EGPKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_EGPKRW', '26', event);" target="_parent">
#
#
#
#
# 					이집트 EGP
#
# 				</a></td>
# <td class="sale">65.03</td>
# <td>0.00</td>
# <td>0.00</td>
# <td>0.00</td>
# <td>0.00</td>
# <td>0.057</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_THBKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_THBKRW', '27', event);" target="_parent">
#
#
#
#
# 					태국 THB
#
# 				</a></td>
# <td class="sale">35.75</td>
# <td>37.53</td>
# <td>33.61</td>
# <td>36.10</td>
# <td>35.40</td>
# <td>0.032</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_SGDKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_SGDKRW', '28', event);" target="_parent">
#
#
#
#
# 					싱가포르 SGD
#
# 				</a></td>
# <td class="sale">834.62</td>
# <td>851.22</td>
# <td>818.02</td>
# <td>842.96</td>
# <td>826.28</td>
# <td>0.736</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_MYRKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_MYRKRW', '29', event);" target="_parent">
#
#
#
#
# 					말레이시아 MYR
#
# 				</a></td>
# <td class="sale">277.42</td>
# <td>294.89</td>
# <td>256.90</td>
# <td>0.00</td>
# <td>274.65</td>
# <td>0.245</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_IDRKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_IDRKRW', '30', event);" target="_parent">
#
#
# 					인도네시아 IDR 100
#
#
#
# 				</a></td>
# <td class="sale">7.96</td>
# <td>8.51</td>
# <td>7.17</td>
# <td>8.03</td>
# <td>7.89</td>
# <td>0.007</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_QARKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_QARKRW', '31', event);" target="_parent">
#
#
#
#
# 					카타르 QAR
#
# 				</a></td>
# <td class="sale">311.61</td>
# <td>0.00</td>
# <td>0.00</td>
# <td>0.00</td>
# <td>0.00</td>
# <td>0.275</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_KZTKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_KZTKRW', '32', event);" target="_parent">
#
#
#
#
# 					카자흐스탄 KZT
#
# 				</a></td>
# <td class="sale">2.99</td>
# <td>0.00</td>
# <td>0.00</td>
# <td>0.00</td>
# <td>0.00</td>
# <td>0.003</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_BNDKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_BNDKRW', '33', event);" target="_parent">
#
#
#
#
# 					브루나이 BND
#
# 				</a></td>
# <td class="sale">834.62</td>
# <td>868.00</td>
# <td>784.55</td>
# <td>0.00</td>
# <td>0.00</td>
# <td>0.736</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_INRKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_INRKRW', '34', event);" target="_parent">
#
#
#
#
# 					인도 INR
#
# 				</a></td>
# <td class="sale">16.23</td>
# <td>0.00</td>
# <td>0.00</td>
# <td>0.00</td>
# <td>0.00</td>
# <td>0.014</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_PKRKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_PKRKRW', '35', event);" target="_parent">
#
#
#
#
# 					파키스탄 PKR
#
# 				</a></td>
# <td class="sale">8.12</td>
# <td>0.00</td>
# <td>0.00</td>
# <td>0.00</td>
# <td>0.00</td>
# <td>0.007</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_BDTKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_BDTKRW', '36', event);" target="_parent">
#
#
#
#
# 					방글라데시 BDT
#
# 				</a></td>
# <td class="sale">13.48</td>
# <td>0.00</td>
# <td>0.00</td>
# <td>0.00</td>
# <td>0.00</td>
# <td>0.012</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_PHPKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_PHPKRW', '37', event);" target="_parent">
#
#
#
#
# 					필리핀 PHP
#
# 				</a></td>
# <td class="sale">21.71</td>
# <td>23.88</td>
# <td>19.93</td>
# <td>21.92</td>
# <td>21.50</td>
# <td>0.019</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_MXNKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_MXNKRW', '38', event);" target="_parent">
#
#
#
#
# 					멕시코 MXN
#
# 				</a></td>
# <td class="sale">58.24</td>
# <td>64.06</td>
# <td>53.35</td>
# <td>58.82</td>
# <td>57.66</td>
# <td>0.051</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_BRLKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_BRLKRW', '39', event);" target="_parent">
#
#
#
#
# 					브라질 BRL
#
# 				</a></td>
# <td class="sale">293.36</td>
# <td>323.28</td>
# <td>269.90</td>
# <td>0.00</td>
# <td>289.84</td>
# <td>0.259</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_VNDKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_VNDKRW', '40', event);" target="_parent">
#
#
#
# 					베트남 VND 100
#
#
# 				</a></td>
# <td class="sale">4.89</td>
# <td>5.46</td>
# <td>4.32</td>
# <td>4.93</td>
# <td>4.85</td>
# <td>0.004</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_ZARKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_ZARKRW', '41', event);" target="_parent">
#
#
#
#
# 					남아프리카 공화국 ZAR
#
# 				</a></td>
# <td class="sale">78.96</td>
# <td>83.69</td>
# <td>72.65</td>
# <td>79.90</td>
# <td>78.02</td>
# <td>0.070</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_RUBKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_RUBKRW', '42', event);" target="_parent">
#
#
#
#
# 					러시아 RUB
#
# 				</a></td>
# <td class="sale">17.18</td>
# <td>18.38</td>
# <td>15.30</td>
# <td>17.35</td>
# <td>17.01</td>
# <td>0.015</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_HUFKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_HUFKRW', '43', event);" target="_parent">
#
#
#
#
# 					헝가리 HUF
#
# 				</a></td>
# <td class="sale">4.04</td>
# <td>4.41</td>
# <td>3.72</td>
# <td>4.08</td>
# <td>4.00</td>
# <td>0.004</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_PLNKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_PLNKRW', '44', event);" target="_parent">
#
#
#
#
# 					폴란드 PLN
#
# 				</a></td>
# <td class="sale">296.75</td>
# <td>320.49</td>
# <td>273.01</td>
# <td>300.01</td>
# <td>293.49</td>
# <td>0.262</td>
# </tr>
# </tbody>
# </table>
# </div>
# <script language="javascript" type="text/javascript">
# 		// 통화명 정렬 - asc, desc
#
# 		// xss 공격 때문에 validation check 추가
# 		regex = new RegExp("^asc$|^desc$");
#
# 		if ("".match(regex)) {
# 			var CURRENT_SORT_ORDER = "";
# 		} else {
# 			var CURRENT_SORT_ORDER = "asc";
# 		}
#
# 		function changeOrder(type) {
# 		var sortOrder = null;
# 		if (CURRENT_SORT_ORDER == "asc") {
# 			sortOrder = "desc";
# 		} else if (CURRENT_SORT_ORDER == "desc") {
# 			sortOrder = "asc";
# 		} else {
# 			sortOrder = "desc";
# 		}
#
# 		if(type == "exchange") {
# 			location.href= "/marketindex/exchangeList.nhn?sortOrder="+sortOrder;
# 		} else {
# 			location.href= "/marketindex/worldExchangeList.nhn?sortOrder="+sortOrder;
# 		}
# 	}
# 	</script>
# <script type="text/javascript">
# </script>
# </body>
# </html>

# %%
cur_name = [td.a.string.strip() for td in soup.select('td.tit')]
cur_name
# Out:
# ['미국 USD',
#  '유럽연합 EUR',
#  '일본 JPY (100엔)',
#  '중국 CNY',
#  '홍콩 HKD',
#  '대만 TWD',
#  '영국 GBP',
#  '오만 OMR',
#  '캐나다 CAD',
#  '스위스 CHF',
#  '스웨덴 SEK',
#  '호주 AUD',
#  '뉴질랜드 NZD',
#  '체코 CZK',
#  '칠레 CLP',
#  '터키 TRY',
#  '몽골 MNT',
#  '이스라엘 ILS',
#  '덴마크 DKK',
#  '노르웨이 NOK',
#  '사우디아라비아 SAR',
#  '쿠웨이트 KWD',
#  '바레인 BHD',
#  '아랍에미리트 AED',
#  '요르단 JOD',
#  '이집트 EGP',
#  '태국 THB',
#  '싱가포르 SGD',
#  '말레이시아 MYR',
#  '인도네시아 IDR 100',
#  '카타르 QAR',
#  '카자흐스탄 KZT',
#  '브루나이 BND',
#  '인도 INR',
#  '파키스탄 PKR',
#  '방글라데시 BDT',
#  '필리핀 PHP',
#  '멕시코 MXN',
#  '브라질 BRL',
#  '베트남 VND 100',
#  '남아프리카 공화국 ZAR',
#  '러시아 RUB',
#  '헝가리 HUF',
#  '폴란드 PLN']

# %%
sale = [ td.string.strip() for td in soup.select('td.sale')]
sale
# Out:
# ['1,134.50',
#  '1,275.52',
#  '1,019.73',
#  '168.53',
#  '144.53',
#  '36.70',
#  '1,473.66',
#  '2,946.60',
#  '845.44',
#  '1,124.32',
#  '120.55',
#  '799.14',
#  '772.25',
#  '49.71',
#  '1.69',
#  '208.66',
#  '0.43',
#  '313.48',
#  '170.97',
#  '130.60',
#  '302.51',
#  '3,731.17',
#  '3,009.20',
#  '308.86',
#  '1,602.29',
#  '65.03',
#  '35.75',
#  '834.62',
#  '277.42',
#  '7.96',
#  '311.61',
#  '2.99',
#  '834.62',
#  '16.23',
#  '8.12',
#  '13.48',
#  '21.71',
#  '58.24',
#  '293.36',
#  '4.89',
#  '78.96',
#  '17.18',
#  '4.04',
#  '296.75']

# %%
ex_info = {
    'Currency' : cur_name,
    'Exchange rate' : sale
}
ex_table = pd.DataFrame(ex_info)
ex_table
# Out:
#          Currency Exchange rate
# 0          미국 USD      1,134.50
# 1        유럽연합 EUR      1,275.52
# 2   일본 JPY (100엔)      1,019.73
# 3          중국 CNY        168.53
# 4          홍콩 HKD        144.53
# 5          대만 TWD         36.70
# 6          영국 GBP      1,473.66
# 7          오만 OMR      2,946.60
# 8         캐나다 CAD        845.44
# 9         스위스 CHF      1,124.32
# 10        스웨덴 SEK        120.55
# 11         호주 AUD        799.14
# 12       뉴질랜드 NZD        772.25
# 13         체코 CZK         49.71
# 14         칠레 CLP          1.69
# 15         터키 TRY        208.66
# 16         몽골 MNT          0.43
# 17       이스라엘 ILS        313.48
# 18        덴마크 DKK        170.97
# 19       노르웨이 NOK        130.60
# 20    사우디아라비아 SAR        302.51
# 21       쿠웨이트 KWD      3,731.17
# 22        바레인 BHD      3,009.20
# 23     아랍에미리트 AED        308.86
# 24        요르단 JOD      1,602.29
# 25        이집트 EGP         65.03
# 26         태국 THB         35.75
# 27       싱가포르 SGD        834.62
# 28      말레이시아 MYR        277.42
# 29  인도네시아 IDR 100          7.96
# 30        카타르 QAR        311.61
# 31      카자흐스탄 KZT          2.99
# 32       브루나이 BND        834.62
# 33         인도 INR         16.23
# 34       파키스탄 PKR          8.12
# 35      방글라데시 BDT         13.48
# 36        필리핀 PHP         21.71
# 37        멕시코 MXN         58.24
# 38        브라질 BRL        293.36
# 39    베트남 VND 100          4.89
# 40  남아프리카 공화국 ZAR         78.96
# 41        러시아 RUB         17.18
# 42        헝가리 HUF          4.04
# 43        폴란드 PLN        296.75

# %%
trs = soup.find('tbody').find_all('tr')
trs[0].find_all('td')[0].string.strip()
# Out:
# '미국 USD'

# %%
item = list()
for i in range(0,len(trs)):
    tds = trs[i].find_all('td')
    item.append([tds[j].string.strip() for j in range(0,len(tds))])
table = pd.DataFrame(item)
table.columns = ('curname','sale','buy','sell','remit','deposit','us_ex')
table
# Out:
#           curname      sale       buy      sell     remit   deposit  us_ex
# 0          미국 USD  1,134.50  1,154.35  1,114.65  1,145.60  1,123.40  1.000
# 1        유럽연합 EUR  1,275.52  1,300.90  1,250.14  1,288.27  1,262.77  1.124
# 2   일본 JPY (100엔)  1,019.73  1,037.57  1,001.89  1,029.72  1,009.74  0.899
# 3          중국 CNY    168.53    176.95    160.11    170.21    166.85  0.149
# 4          홍콩 HKD    144.53    147.37    141.69    145.97    143.09  0.127
# 5          대만 TWD     36.70     41.50     34.14      0.00      0.00  0.032
# 6          영국 GBP  1,473.66  1,502.69  1,444.63  1,488.39  1,458.93  1.299
# 7          오만 OMR  2,946.60  3,208.84  2,769.81      0.00      0.00  2.597
# 8         캐나다 CAD    845.44    862.09    828.79    853.89    836.99  0.745
# 9         스위스 CHF  1,124.32  1,146.46  1,102.18  1,135.56  1,113.08  0.991
# 10        스웨덴 SEK    120.55    123.50    117.60    121.75    119.35  0.106
# 11         호주 AUD    799.14    814.88    783.40    807.13    791.15  0.704
# 12       뉴질랜드 NZD    772.25    787.46    757.04    779.97    764.53  0.681
# 13         체코 CZK     49.71     53.93     45.24     50.25     49.17  0.044
# 14         칠레 CLP      1.69      1.82      1.56      0.00      0.00  0.002
# 15         터키 TRY    208.66    240.16    188.22    210.95    206.37  0.184
# 16         몽골 MNT      0.43      0.00      0.00      0.00      0.00  0.000
# 17       이스라엘 ILS    313.48    344.82    288.41      0.00      0.00  0.276
# 18        덴마크 DKK    170.97    175.15    166.79    172.67    169.27  0.151
# 19       노르웨이 NOK    130.60    133.79    127.41    131.90    129.30  0.115
# 20    사우디아라비아 SAR    302.51    321.56    281.64    305.53    299.49  0.267
# 21       쿠웨이트 KWD  3,731.17  3,973.69  3,432.68  3,768.48  3,693.86  3.289
# 22        바레인 BHD  3,009.20  3,201.78  2,768.47  3,039.29  2,979.11  2.652
# 23     아랍에미리트 AED    308.86    325.84    287.55    311.94    305.78  0.272
# 24        요르단 JOD  1,602.29  1,744.89  1,474.11      0.00      0.00  1.412
# 25        이집트 EGP     65.03      0.00      0.00      0.00      0.00  0.057
# 26         태국 THB     35.75     37.53     33.61     36.10     35.40  0.032
# 27       싱가포르 SGD    834.62    851.22    818.02    842.96    826.28  0.736
# 28      말레이시아 MYR    277.42    294.89    256.90      0.00    274.65  0.245
# 29  인도네시아 IDR 100      7.96      8.51      7.17      8.03      7.89  0.007
# 30        카타르 QAR    311.61      0.00      0.00      0.00      0.00  0.275
# 31      카자흐스탄 KZT      2.99      0.00      0.00      0.00      0.00  0.003
# 32       브루나이 BND    834.62    868.00    784.55      0.00      0.00  0.736
# 33         인도 INR     16.23      0.00      0.00      0.00      0.00  0.014
# 34       파키스탄 PKR      8.12      0.00      0.00      0.00      0.00  0.007
# 35      방글라데시 BDT     13.48      0.00      0.00      0.00      0.00  0.012
# 36        필리핀 PHP     21.71     23.88     19.93     21.92     21.50  0.019
# 37        멕시코 MXN     58.24     64.06     53.35     58.82     57.66  0.051
# 38        브라질 BRL    293.36    323.28    269.90      0.00    289.84  0.259
# 39    베트남 VND 100      4.89      5.46      4.32      4.93      4.85  0.004
# 40  남아프리카 공화국 ZAR     78.96     83.69     72.65     79.90     78.02  0.070
# 41        러시아 RUB     17.18     18.38     15.30     17.35     17.01  0.015
# 42        헝가리 HUF      4.04      4.41      3.72      4.08      4.00  0.004
# 43        폴란드 PLN    296.75    320.49    273.01    300.01    293.49  0.262

# %% [markdown]
# ---
# ## Example 2 - 네이버 영화에서 현재 인기 영화 순위 정보 가져오기
#
# https://github.com/mssung94/ssmc_python_using_bigdata/blob/master/data_crawling/step1/bs4_ex2_naver_movie.ipynb

# %%
search_time = '20190309'
url = 'https://movie.naver.com/movie/sdb/rank/rmovie.nhn?sel=cur&tg=0&date=%s'
page = urlopen(url % search_time)
soup = BeautifulSoup(page,'html.parser')

# %%
divs = soup.find_all('div',class_='tit5')
points = soup.find_all('td','point')
divs[:1]
# Out:
# [<div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=171539" title="그린 북">그린 북</a>
#  </div>]
